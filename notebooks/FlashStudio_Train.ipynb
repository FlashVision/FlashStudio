# %% [markdown]
# # ⚡ FlashStudio — Training
#
# Train FlashDet object detection models with an interactive UI.
#
# **Requirements:** GPU runtime (T4 or better)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FlashVision/FlashStudio/blob/main/notebooks/FlashStudio_Train.ipynb)

# %%
# Step 1: Install FlashStudio + FlashDet
# !pip install -q flashstudio flashdet

# %%
# Step 2 (Optional): Set ngrok token for stable public URL
# Get your free token at https://dashboard.ngrok.com/get-started/your-authtoken
import os
os.environ["NGROK_TOKEN"] = ""  # paste your token here (optional)

# %%
# Step 3: Launch FlashStudio Training UI
from flashstudio import launch
launch()

# %% [markdown]
# ---
# ## 📖 Manual Training (Alternative)
#
# If you prefer CLI-based training without the UI:

# %%
# CLI-based training (without UI)
# !flashdet train \
#     --model flashdet_pico \
#     --data /content/datasets/coco128/annotations/instances_train.json \
#     --img-dir /content/datasets/coco128/images/train \
#     --epochs 100 \
#     --batch-size 16 \
#     --lr 0.001 \
#     --amp
