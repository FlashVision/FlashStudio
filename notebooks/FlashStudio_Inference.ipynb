# %% [markdown]
# # ⚡ FlashStudio — Inference
#
# Run FlashDet object detection on your images with an interactive UI.
#
# **Requirements:** GPU runtime recommended (CPU also works)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FlashVision/FlashStudio/blob/main/notebooks/FlashStudio_Inference.ipynb)

# %%
# Step 1: Install FlashStudio + FlashDet
# !pip install -q flashstudio flashdet

# %%
# Step 2 (Optional): Set ngrok token for stable public URL
import os
os.environ["NGROK_TOKEN"] = ""  # paste your token here (optional)

# %%
# Step 3: Launch FlashStudio Inference UI
from flashstudio import launch
launch()

# %% [markdown]
# ---
# ## 📖 Python API (Alternative)
#
# If you prefer programmatic inference without the UI:

# %%
# Programmatic inference (without UI)
# from flashdet import FlashDetPredictor
# import cv2
#
# predictor = FlashDetPredictor(
#     model_name="flashdet_pico",
#     weights="path/to/model_best_inference.pth",
#     conf_threshold=0.25,
# )
#
# image = cv2.imread("test.jpg")
# results = predictor.predict(image)
#
# for det in results:
#     print(f"{det['class']}: {det['confidence']:.2f} at {det['bbox']}")
